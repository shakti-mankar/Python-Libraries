# %%
# create an array by passing tuple

data = np.array([1,2,3,4])

print(data)
# Out:
# [1 2 3 4]

# %%
import numpy as np

# create an array by passing list 

data = np.array((1,2,3,4))

print(data)
# Out:
# [1 2 3 4]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 8
#       4
#       5 data = np.array((1,2,3,4))
#       6
#       7 print(data)
# ----> 8 print(np.data)
#
# File c:\Users\shakti\Desktop\Data Science\Python Libraries\env\Lib\site-packages\numpy\__init__.py:805, in __getattr__(attr)
#     802     import numpy.char as char
#     803     return char.chararray
# --> 805 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'data'
