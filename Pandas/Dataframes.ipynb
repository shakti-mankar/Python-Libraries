# %%
import pandas  as pd

# %%
data = [["john",23,'Mumbai'],
        ["ALice",28,'Delhi'],
        ["Harry",30,'Chennai'],
        ["Sam",26,'Bhopal']]

df = pd.DataFrame(data , columns=["Name","Age","City"])

df
# Out:
#     Name  Age     City
# 0   john   23   Mumbai
# 1  ALice   28    Delhi
# 2  Harry   30  Chennai
# 3    Sam   26   Bhopal

# %%
data = { 
"Name" : ["John","Alice","Harry","Sam"],
"Age" : [23,28,30,26],
"City" : ["Mumbai","Delhi","Chennai","Bhopal"]
}


df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age     City
# 0   John   23   Mumbai
# 1  Alice   28    Delhi
# 2  Harry   30  Chennai
# 3    Sam   26   Bhopal

# %%
df.set_index("Name", inplace = True)

df
# Out:
#        Age     City
# Name
# John    23   Mumbai
# Alice   28    Delhi
# Harry   30  Chennai
# Sam     26   Bhopal

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     Name  Age     City
# 0   John   23   Mumbai
# 1  Alice   28    Delhi
# 2  Harry   30  Chennai
# 3    Sam   26   Bhopal

# %%
df.shape
# Out:
# (4, 3)

# %%
df = pd.read_csv('newdata.csv')

df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='str')

# %%
df.values
# Out:
# array([[1, 1, 'Chips and Fresh Tomato Salsa', nan, '$2.39'],
#        [1, 1, 'Izze', '[Clementine]', '$3.39'],
#        [1, 1, 'Nantucket Nectar', '[Apple]', '$3.39'],
#        ...,
#        [1834, 1, 'Chicken Salad Bowl',
#         '[Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Guacamole, Lettuce]]',
#         '$11.25'],
#        [1834, 1, 'Chicken Salad Bowl',
#         '[Fresh Tomato Salsa, [Fajita Vegetables, Lettuce]]', '$8.75'],
#        [1834, 1, 'Chicken Salad Bowl',
#         '[Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Lettuce]]',
#         '$8.75']], shape=(4622, 5), dtype=object)

# %%
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN      $2.39
# 1                                       [Clementine]      $3.39
# 2                                            [Apple]      $3.39
# 3                                                NaN      $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $16.98

# %%
df.tail(5)
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...     $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...     $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...      $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...      $8.75

# %%
df.sample(5)
# Out:
#       order_id  quantity            item_name  \
# 1504       611         1         Chicken Bowl
# 1669       675         1  Barbacoa Soft Tacos
# 3834      1537         1        Steak Burrito
# 1448       588         1      Chicken Burrito
# 2904      1155         1    Canned Soft Drink
#
#                                      choice_description item_price
# 1504  [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream...      $8.75
# 1669  [Tomatillo Red Chili Salsa, [Rice, Cheese, Sou...      $9.25
# 3834  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...      $9.25
# 1448  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $11.25
# 2904                                        [Diet Coke]      $1.25

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   str
#  3   choice_description  3376 non-null   str
#  4   item_price          4622 non-null   str
# dtypes: int64(2), str(3)
# memory usage: 180.7 KB

# %%
df.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
df.isnull().sum().sum()
# Out:
# np.int64(1246)

# %%
df.duplicated().sum()
# Out:
# np.int64(59)

# %%
df.rename( columns = {'order_id' : 'order'})
# Out:
#       order  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# ...     ...       ...                                    ...
# 4617   1833         1                          Steak Burrito
# 4618   1833         1                          Steak Burrito
# 4619   1834         1                     Chicken Salad Bowl
# 4620   1834         1                     Chicken Salad Bowl
# 4621   1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN      $2.39
# 1                                          [Clementine]      $3.39
# ...

# %%
df.rename( columns = {'order_id' : 'order'}, inplace = True)

# %%
# df.set_index("order_id",inplace= True)

# %%
df
# Out:
#       order  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# ...     ...       ...                                    ...
# 4617   1833         1                          Steak Burrito
# 4618   1833         1                          Steak Burrito
# 4619   1834         1                     Chicken Salad Bowl
# 4620   1834         1                     Chicken Salad Bowl
# 4621   1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN      $2.39
# 1                                          [Clementine]      $3.39
# ...

# %%
df['item_name'].dtype

df['item_name'].sum()

df['quantity'].max()
df['quantity'].min()
df['quantity'].var()
df['quantity'].std()
df['quantity'].median()


df.sum(numeric_only = True)

df.mean(numeric_only = True)

df.mode()
# Out:
#    order  quantity     item_name choice_description item_price
# 0    926         1  Chicken Bowl        [Diet Coke]      $8.75

# %%
df
# Out:
#       order  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# ...     ...       ...                                    ...
# 4617   1833         1                          Steak Burrito
# 4618   1833         1                          Steak Burrito
# 4619   1834         1                     Chicken Salad Bowl
# 4620   1834         1                     Chicken Salad Bowl
# 4621   1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN      $2.39
# 1                                          [Clementine]      $3.39
# ...

# %%
df.rename(columns={ 'order_id': 'id'}, inplace=True)

df
# Out:
#       order  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# ...     ...       ...                                    ...
# 4617   1833         1                          Steak Burrito
# 4618   1833         1                          Steak Burrito
# 4619   1834         1                     Chicken Salad Bowl
# 4620   1834         1                     Chicken Salad Bowl
# 4621   1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN      $2.39
# 1                                          [Clementine]      $3.39
# ...

# %%
df['item_name']  # for targeting single column 

# df[['id','item_name']] # for targeting multiple columns 

# df[['id','item_name','item_price']]

df[0:4] # targeting rows
df[0:10]

df.iloc[0:4] # targeting rows
# Out:
#    order  quantity                              item_name choice_description  \
# 0      1         1           Chips and Fresh Tomato Salsa                NaN
# 1      1         1                                   Izze       [Clementine]
# 2      1         1                       Nantucket Nectar            [Apple]
# 3      1         1  Chips and Tomatillo-Green Chili Salsa                NaN
#
#   item_price
# 0      $2.39
# 1      $3.39
# 2      $3.39
# 3      $2.39

# %%
df['item_price']
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: str

# %%
# df['item_price'] = df['item_price'].str.replace('$','',regex=False)

# df.['item_price'].dtype

# %%
# df['item_price'].astype(int)

df['item_price'] = df['item_price'].str.replace('$','',regex=False)

df['item_price'].astype('float')

df['item_price'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
# # df['item_price'].isnull().sum()

# df['item_price'] = pd.to_numeric(df['item_price'])

# df['item_price'].between(11,16)

# df[df['item_price'].between(11,16)]


# # df.drop(columns = ['item_price'], inplace=True) 

# df = df.drop (columns= ['item_price'] )

# df['item_price'] = df['item_price'].str.replace('$','',regex=False)

# df['item_price'].unique()

# df['item_price'].dtype.between(11,6)



# m = df['item_price'].between(11,16)

# df[m]

# %%
df.duplicated().sum()
# Out:
# np.int64(59)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(1228)

# %%
# df.dropna(inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(1228)

# %%
# df.fillna(,inplace=True)

# %%
# m = df['choice_description'].mode()

# %%
# df.fillna(m,inplace=True)

# %%
df.head(5)
# Out:
#    order  quantity                              item_name  \
# 0      1         1           Chips and Fresh Tomato Salsa
# 1      1         1                                   Izze
# 2      1         1                       Nantucket Nectar
# 3      1         1  Chips and Tomatillo-Green Chili Salsa
# 4      2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN       2.39
# 1                                       [Clementine]       3.39
# 2                                            [Apple]       3.39
# 3                                                NaN       2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...      16.98

# %%
df
# Out:
#       order  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# ...     ...       ...                                    ...
# 4617   1833         1                          Steak Burrito
# 4618   1833         1                          Steak Burrito
# 4619   1834         1                     Chicken Salad Bowl
# 4620   1834         1                     Chicken Salad Bowl
# 4621   1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN       2.39
# 1                                          [Clementine]       3.39
# ...

# %%
# df['quantity'] = df['quantity'].apply(lambda x:x+1)

# %%
df.head(5)
# Out:
#    order  quantity                              item_name  \
# 0      1         1           Chips and Fresh Tomato Salsa
# 1      1         1                                   Izze
# 2      1         1                       Nantucket Nectar
# 3      1         1  Chips and Tomatillo-Green Chili Salsa
# 4      2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN       2.39
# 1                                       [Clementine]       3.39
# 2                                            [Apple]       3.39
# 3                                                NaN       2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...      16.98

# %%
def incre(x):
    if x>10:
        x+=1

    else:
        x+=3

# %%
df['quantity'] = df['quantity'].apply(incre)

# %%
df
# Out:
#       order quantity                              item_name  \
# 0         1     None           Chips and Fresh Tomato Salsa
# 1         1     None                                   Izze
# 2         1     None                       Nantucket Nectar
# 3         1     None  Chips and Tomatillo-Green Chili Salsa
# 4         2     None                           Chicken Bowl
# ...     ...      ...                                    ...
# 4617   1833     None                          Steak Burrito
# 4618   1833     None                          Steak Burrito
# 4619   1834     None                     Chicken Salad Bowl
# 4620   1834     None                     Chicken Salad Bowl
# 4621   1834     None                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN       2.39
# 1                                          [Clementine]       3.39
# ...

# %%
def item_incre(x):
    if x>10:
        x+=1

    else:
        x+=3 
    return x

# %%
# df['new_price'] = df['item_price'].apply(item_incre)
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df['item_name'].unique()
# Out:
# <StringArray>
# [         'Chips and Fresh Tomato Salsa',
#                                   'Izze',
#                       'Nantucket Nectar',
#  'Chips and Tomatillo-Green Chili Salsa',
#                           'Chicken Bowl',
#                          'Side of Chips',
#                          'Steak Burrito',
#                       'Steak Soft Tacos',
#                    'Chips and Guacamole',
#                   'Chicken Crispy Tacos',
#                     'Chicken Soft Tacos',
#                        'Chicken Burrito',
#                            'Canned Soda',
#                       'Barbacoa Burrito',
#                       'Carnitas Burrito',
#                          'Carnitas Bowl',
#                          'Bottled Water',
#  'Chips and Tomatillo Green Chili Salsa',
#                          'Barbacoa Bowl',
#                                  'Chips',
#                     'Chicken Salad Bowl',
#                             'Steak Bowl',
# ...

# %%
df['item_name'].nunique()
# Out:
# 50

# %%
z = df.groupby('item_name')

# %%
y = z.get_group('Canned Soda')

# %%
y
# Out:
#       order  quantity    item_name choice_description item_price
# 18        9         2  Canned Soda           [Sprite]       2.18
# 28       14         1  Canned Soda       [Dr. Pepper]       1.09
# 51       23         2  Canned Soda     [Mountain Dew]       2.18
# 53       24         1  Canned Soda           [Sprite]       1.09
# 107      47         1  Canned Soda       [Dr. Pepper]       1.09
# ...     ...       ...          ...                ...        ...
# 3897   1562         1  Canned Soda     [Mountain Dew]       1.09
# 3926   1575         1  Canned Soda       [Dr. Pepper]       1.09
# 3936   1578         1  Canned Soda  [Diet Dr. Pepper]       1.09
# 4008   1604         1  Canned Soda        [Diet Coke]       1.09
# 4051   1621         1  Canned Soda           [Sprite]       1.09
#
# [102 rows x 5 columns]

# %%
df['item_price'].dtype

df['item_price'].astype('float')
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4563, dtype: float64

# %%
df['item_price'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>
