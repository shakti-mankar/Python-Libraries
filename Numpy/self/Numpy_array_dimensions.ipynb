# %%
import numpy as np

# Zero dimension 

n = np.array(25)

print("Dimensions : " , n.ndim)

# %%
# import numpy as np 

# b = np.arange(1,91).reshape(3,3)

# print(b)


import numpy as np 

b = np.array([[10,20,30],
             [40,50,60],
             [70,80,90]])

# print(b)

# print(b[1:2 , :3 ])

# print(b[ -2:-1 , -3: ])

# print(b[1:2 , :3])


# print(b[0:1 , :3 ])

# print(b[2:3 , 1:2])

# print(b[0:1 ,0:1 ])

# print(b[0:1, 1:3])

print(b[0: , 0:1 ])
# Out:
# [[10]
#  [40]
#  [70]]

# %%
import numpy as np

# Zero dimension 

n = np.array(25)

print("Dimensions : " , n.ndim)
