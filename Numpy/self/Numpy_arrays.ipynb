# %%
# Two dimension 

data = np.array([[1,2,3,4],[5,6,7,8]])

print(data)

print("Dimensions :" , data.ndim)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]
# Dimensions : 2

# %%
# One dimension 
import numpy as np
data = np.array([1,2,3,4,5])

print(data)

print("Dimensions : " , data.ndim)
# Out:
# [1 2 3 4 5]
# Dimensions :  1

# %%
import numpy as np

# Zero dimension 

n = np.array(25)

print("Dimensions : " , n.ndim)
# Out:
# Dimensions :  0

# %%
# create an array by passing tuple

data = np.array([1,2,3,4])

print(data)
# Out:
# [1 2 3 4]

# %%
import numpy as np

# create an array by passing list 

data = np.array((1,2,3,4))

print(data)
# Out:
# [1 2 3 4]
