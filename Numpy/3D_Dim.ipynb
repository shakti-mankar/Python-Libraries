# %%
# 3D SLICING ([BLOCK,ROW:COLUMN,DIRCTION])
import numpy as np
a=np.array([
                [
                    [1,2],
                    [3,4],
                ],  
                [
                    [5,6],
                    [7,8]
                ]
            ])


# 3 
# print(a[:1,1:,:1])

# 6
# print(a[1, 0:1 , 1:2])

# 2B , 5,6,7,8
# print(a[1: , 0: , :])


# 1b , 1,2,3,4
# print(a[0:1 , 0: , :])


# + , - puraa

# print(a[0: , 0: , 0:])

# print(a[-2: , 0: , 0:])


# print(a[0: , 0:1 , 0:])

# print(a, "\n")

# print(a[0: , 1: , 0: ])

# print(a[0:-1 , -1: , :])

# print(a[-2: , 0:-1 , -1: ])
# Out:
# [[[2]]
#
#  [[6]]]
