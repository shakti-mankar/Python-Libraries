# %%
import numpy as np 

a = np.array([1,2,3,4])

print(np.mean(a))
print(np.median(a))
# Out:
# 2.5
# 2.5

# %%
b = np.array([10,20,30,40,60])

print(np.std(b))

print(np.var(b))

print(np.min(b))
print(np.max(b))

print(np.percentile(b,100))
# Out:
# 17.204650534085253
# 296.0
# 10
# 60
# 60.0
